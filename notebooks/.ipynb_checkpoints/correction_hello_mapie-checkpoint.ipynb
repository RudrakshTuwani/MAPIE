# %% [markdown]
# # Hello MAPIE !

# %% [markdown]
# Dans ce premier exercice, nous allons estimer nos premières incertitudes avec MAPIE sur un jeu de données linéaire uni-dimensionnel.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
import plotly.graph_objects as go

# %% [markdown]
# **Exercice.** Importons le régresseur de MAPIE `MapieRegressor` ainsi que la fonction `coverage_score` permettant d'estimer le taux de couverture.

# %%
from mapie.regression import MapieRegressor
from mapie.metrics import regression_coverage_score

# %% [markdown]
# Créons nos données linéaires bruitées avec scikit-learn.

# %%
regressor = LinearRegression()
X, y = make_regression(n_samples=500, n_features=1, noise=20, random_state=59)

# %% [markdown]
# **Exercice.** Initialisons `MapieRegressor` avec la méthode "plus" puis entraînons le modèle sur nos données générées.

# %%
mapie = MapieRegressor(regressor, method="plus", cv=5)  # correction
mapie.fit(X, y)  # correction
# Out:
# MapieRegressor(cv=5, estimator=LinearRegression())

# %% [markdown]
# **Exercice.** Calculons nos prédictions sans définir le paramètre `alpha`.

# %%
y_pred = mapie.predict(X)  # correction

# %% [markdown]
# **Question.** Quel est l'objet retourné par `MapieRegressor` et quelle est sa taille ?

# %%
print(type(y_pred), y_pred.shape)  # correction
# Out:
# <class 'numpy.ndarray'> (500,)

# %% [markdown]
# **Exercice.** Estimons maintenant les incertitudes pour deux valeurs de alpha (0.32 et 0.05). Pour ce faire, ajouter le paramètre `alpha` comme argument dans le `predict` en tant que liste.

# %%
alpha = [0.32, 0.05]  # correction
y_preds = mapie.predict(X, alpha=alpha)  # correction

# %% [markdown]
# **Question.** Quel est l'objet retourné par `MapieRegressor` ?

# %%
print(type(y_preds), len(y_preds))  # correction
# Out:
# <class 'tuple'> 2

# %% [markdown]
# **Exercice.** Calculons maintenant le taux de couverture pour les deux valeurs de alpha.

# %%
coverage_scores = [  # correction
    regression_coverage_score(y, y_preds[1][:, 0, i], y_preds[1][:, 1, i])  # correction
    for i, _ in enumerate(alpha)  # correction
]  # correction

# %% [markdown]
# Visualisons enfin les intervalles de prédiction estimés.

# %%
fig = go.Figure()

# lower/upper bounds
order = np.argsort(X[:, 0])
fig.add_trace(go.Scatter(
    name="lower bound",
    x=X[order].ravel(),
    y=y_preds[1][:, 0, 0][order],
    mode="lines",
    line=dict(color="#ff7f0e", dash='solid')
))
fig.add_trace(go.Scatter(
    name="upper bound",
    x=X[order].ravel(),
    y=y_preds[1][:, 1, 0][order],
    mode="lines",
    fill="tonexty",
    line=dict(color="#ff7f0e", dash='solid')
))

# predictions
fig.add_trace(go.Scatter(
    name="predictions",
    x=X.ravel(),
    y=y_preds[0],
    mode="lines",
    line=dict(color="#ff7f0e", dash='solid')
))

# data
fig.add_trace(go.Scatter(
    name="data",
    x=X.ravel(),
    y=y,
    mode="markers",
    marker=dict(color="#1f77b4", size=4),
))
fig.update_layout(
    autosize=False,
    width=600,
    height=500,
    xaxis_title="x",
    yaxis_title="y",
    hovermode="x",
    showlegend=False
)
fig.show()
# Out:
# <div>                            <div id="fe733099-9462-47ff-a64c-020fc4f5ab20" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe733099-9462-47ff-a64c-020fc4f5ab20")) {                    Plotly.newPlot(                        "fe733099-9462-47ff-a64c-020fc4f5ab20",                        [{"line":{"color":"#ff7f0e","dash":"solid"},"mode":"lines","name":"lower bound","type":"scatter","x":[-3.1726063431320157,-3.052292530224298,-2.93346073525419,-2.889359539754725,-2.524291636678002,-2.4055123407345715,-2.367083573095155,-2.34531679268782,-2.2945964804313674,-2.1991502118909283,-2.1946682159357196,-2.178048207944226,-2.159264773237686,-2.1394172387591786,-1.9253481178936218,-1.909701477550812,-1.897924305352429,-1.8806913199805875,-1.8232724408716254,-1.781985815241219,-1.7200308748529185,-1.7132533271116113,-1.7059208468725278,-1.6803360899885307,-1.6692835213947237,-1.6689413969914966,-1.6013591104153584,-1.5814824230496125,-1.5621229076029333,-1.553520822724052,-1.5343679990508508,-1.513967475643804,-1.503917604163032,-1.4689586578775318,-1.453448088015352,-1.444022833376941,-1.431363616016203,-1.426498305111843,-1.4161329504658495,-1.410088497297145,-1.3468858955929852,-1.338265234576311,-1.3227558979609133,-1.2953339786466154,-1.2892639659406928,-1.2835812967516238,-1.28104841008426,-1.2638075687264057,-1.2613799985414074,-1.259974465632908,-1.257108088155559,-1.2418213042080768,-1.2350490551023339,-1.2303917038302592,-1.226970745335236,-1.2227511338701607,-1.2119070791223225,-1.209857808530495,-1.2057243531080524,-1.2041276201750324,-1.1920671823882145,-1.1681459894356567,-1.1572740649066975,-1.1445919873592985,-1.1406384546646577,-1.1392023642786715,-1.1380612307405178,-1.13348884620247,-1.1232116052104149,-1.12232182563949,-1.1218375345694687,-1.1157419068601295,-1.1017975760158731,-1.1007039712315163,-1.076982956050875,-1.070601216382956,-1.0697130501268757,-1.0620716835207695,-1.0606726853947221,-1.0586651628450694,-1.0574188909399278,-1.0309436261675178,-1.0285913064400236,-1.0079443119765867,-0.9937604457426868,-0.992588744279292,-0.9891621226798498,-0.9886902260867952,-0.9870137004302758,-0.9821352212247924,-0.9698890754557737,-0.9624658921509283,-0.9607706005115155,-0.9577204979621378,-0.9423199495834671,-0.9412284323674236,-0.9347720172540854,-0.930587452829091,-0.9290695822403314,-0.9247479379075986,-0.9205461802597259,-0.9109394477433523,-0.8985580864438951,-0.8900924988208263,-0.8895113473735371,-0.8880001422879655,-0.8756024318266525,-0.873681816253643,-0.8669628144098506,-0.8598154719295842,-0.8499967882871964,-0.8488111309773588,-0.8314797050173609,-0.8264299717164802,-0.8253036537382383,-0.8182804357216145,-0.8079529858500142,-0.8060810304943229,-0.8036949557708072,-0.7877471570393029,-0.7696159591773416,-0.7677764190539744,-0.7635719903721792,-0.7546815113586696,-0.7516603513849358,-0.7440280433017775,-0.7196004322343685,-0.7157603190908531,-0.7035309934520193,-0.7001112139335568,-0.6982301642682317,-0.6716887445961858,-0.6635464766358433,-0.6615998134944114,-0.6614526077315506,-0.6576315244926401,-0.6550410392940508,-0.6394868185516177,-0.6380395774239263,-0.6301373068776522,-0.6173098179133976,-0.609387494008455,-0.6092527537139856,-0.588779171484598,-0.5737541238940298,-0.5691524456241472,-0.566649650136026,-0.5647067649138332,-0.5642358242904395,-0.5535148820512298,-0.5461751978586435,-0.5429051024810125,-0.5397975932014449,-0.5267220443803647,-0.5228568310003618,-0.5185535957503503,-0.5165179110394608,-0.5155904786220339,-0.5124728111509183,-0.500510003310936,-0.4942079493812812,-0.4921655701333879,-0.49024521147998196,-0.4886581489478422,-0.48698218883013844,-0.46963000391088455,-0.4659152950222226,-0.4522931103307149,-0.45205239264334857,-0.44618816346717527,-0. ...
